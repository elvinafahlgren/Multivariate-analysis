# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1599/4073958682.py in <module>
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.image as mpimg
#       4 import seaborn as sns
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'numpy'

# %%
plt.figure(figsize=(10,10))

plt.subplot(221)
x = np.linspace(-2,2)
y = np.linspace(-2,2)
X, Y = np.meshgrid(x, y)
Z1=3*pow(X,2)-5*pow(Y,2)
plt.contour(X,Y,Z1, levels=15)

plt.subplot(222)
x = np.linspace(-2,2)
y = np.linspace(-2,2)
X, Y = np.meshgrid(x, y)
Z2=3*Y-5*X+1
plt.contour(X,Y,Z2, levels=15)

plt.subplot(223)
x = np.linspace(-2,2)
y = np.linspace(-2,2)
X, Y = np.meshgrid(x, y)
Z3=3*X-5*Y+1
plt.contour(X,Y,Z3, levels=15)

plt.subplot(224)
x = np.linspace(-2,2)
y = np.linspace(-2,2)
X, Y = np.meshgrid(x, y)
Z4=3*pow(X,2)+5*pow(Y,2)
plt.contour(X,Y,Z4, levels=15)

plt.show()
