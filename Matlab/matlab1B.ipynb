# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

# %%
def f(x, y):
    return (x*y+4)**(3/4)

x = np.linspace(-2,2)
y = np.linspace(-2,2)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')

# %%
def f(x, y):
    return y*np.exp(1)**((x**2+y**2)**0.75)

x = np.linspace(-2,2)
y = np.linspace(-2,2)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')

# %%
def f(x, y):
    return x*np.exp(1)**(-(x**2+y**2)**0.5)

x = np.linspace(-2,2)
y = np.linspace(-2,2)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')

# %%
def f(x, y):
    return np.sqrt(np.sqrt(x**2+4))

x = np.linspace(-2,2)
y = np.linspace(-2,2)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
